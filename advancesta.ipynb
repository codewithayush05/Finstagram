# %%
# question1

# %%
"""The Probability Density Function (PDF) is a concept in probability and statistics that describes the likelihood of a continuous random variable taking on a specific value. It is often denoted as f(x) and is used to represent the probability distribution of a continuous random variable. Unlike discrete probability mass functions, which assign probabilities to individual values, the PDF assigns probabilities to ranges of values. In essence, the PDF describes how the probability is distributed across the possible outcomes of a continuous random variable."""
# Out:
# 'The Probability Density Function (PDF) is a concept in probability and statistics that describes the likelihood of a continuous random variable taking on a specific value. It is often denoted as f(x) and is used to represent the probability distribution of a continuous random variable. Unlike discrete probability mass functions, which assign probabilities to individual values, the PDF assigns probabilities to ranges of values. In essence, the PDF describes how the probability is distributed across the possible outcomes of a continuous random variable.'

# %%
# question2

# %%
"""Discrete Probability Distribution: These distributions are defined for discrete random variables, which take on specific, distinct values. Examples include the Binomial, Poisson, and Geometric distributions.

Continuous Probability Distribution: These distributions are defined for continuous random variables, which can take on any value within a range. Examples include the Normal (Gaussian), Exponential, and Uniform distributions.

Bernoulli Distribution: A simple discrete distribution used for modeling binary outcomes, like success/failure or yes/no.

Binomial Distribution: Represents the number of successes in a fixed number of independent Bernoulli trials.

Poisson Distribution: Models the number of events occurring in a fixed interval of time or space, assuming a known average rate of occurrence.

Normal Distribution (Gaussian Distribution): Often referred to as the bell curve, it is widely used due to its properties and describes many natural phenomena.

Exponential Distribution: Models the time between events in a Poisson process, such as the time between arrivals of customers at a service center.

Uniform Distribution: All outcomes within a given interval are equally likely.

Gamma Distribution: Extends the exponential distribution and is used in various fields, including physics and engineering.

Chi-Square Distribution: Arises in statistical inference, especially in hypothesis testing."""
# Out:
# 'Discrete Probability Distribution: These distributions are defined for discrete random variables, which take on specific, distinct values. Examples include the Binomial, Poisson, and Geometric distributions.\n\nContinuous Probability Distribution: These distributions are defined for continuous random variables, which can take on any value within a range. Examples include the Normal (Gaussian), Exponential, and Uniform distributions.\n\nBernoulli Distribution: A simple discrete distribution used for modeling binary outcomes, like success/failure or yes/no.\n\nBinomial Distribution: Represents the number of successes in a fixed number of independent Bernoulli trials.\n\nPoisson Distribution: Models the number of events occurring in a fixed interval of time or space, assuming a known average rate of occurrence.\n\nNormal Distribution (Gaussian Distribution): Often referred to as the bell curve, it is widely used due to its properties and describes many natural phenomena.\n\nExponential
# ...

# %%
# question3

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats


mu = 0
std = 1
snd = stats.norm(mu, std)


x = np.linspace(-5, 5, 100)

plt.figure(figsize=(7.5,7.5))
plt.plot(x, snd.pdf(x))
plt.xlim(-5, 5)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('Values of Random Variable X', fontsize='15')
plt.ylabel('Probability', fontsize='15')
plt.show()

# %%
# question4

# %%
"""It models the number of successes (e.g., heads in coin flips) in a fixed number of independent Bernoulli trials.
Parameters: n (number of trials) and p (probability of success in each trial).
Discrete distribution with values from 0 to n.
Mean (expected value): μ = np.
Variance: σ^2 = np(1-p).
The trials are assumed to be independent and have the same probability of success (p)."""
# Out:
# 'It models the number of successes (e.g., heads in coin flips) in a fixed number of independent Bernoulli trials.\nParameters: n (number of trials) and p (probability of success in each trial).\nDiscrete distribution with values from 0 to n.\nMean (expected value): μ = np.\nVariance: σ^2 = np(1-p).\nThe trials are assumed to be independent and have the same probability of success (p).'

# %%
# question5

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n=1000
p=0.4
sample=np.random.binomial(n=1,p=p,size=n)
plt.hist(sample, bins=np.arange(-0.5, 2.6, 1), density=True, alpha=0.6)
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution (n=1000, p=0.4)')
plt.xticks([0, 1])
plt.show()

# %%
# question6

# %%
def poisson_cdf(k, mean):
    
    cdf = 0
    for i in range(k + 1):
        cdf += (math.exp(-mean) * mean**i) / math.factorial(i)
    return cdf

# %%
poisson_cdf(10,3)
# Out:
# 0.9997076630493528

# %%
# question7

# %%
"""Binomial Distribution:
Models the number of successes in a fixed number of independent Bernoulli trials (e.g., coin flips).
Parameters: n (number of trials) and p (probability of success in each trial).
Discrete distribution with values from 0 to n.
Assumes a fixed number of trials and assesses the probability of obtaining a specific number of successes.
Appropriate when events are discrete and independent with a clear success/failure outcome.
Poisson Distribution:
Models the number of events occurring in a fixed interval of time or space, given a known average rate of occurrence.
Parameter: λ (average rate of occurrence).
Discrete distribution with values from 0 to infinity.
Assumes an infinite number of trials or events and assesses the probability of obtaining a specific count of events.
Appropriate for rare events with a known average rate (e.g., customer arrivals in a minute)."""
# Out:
# 'Binomial Distribution:\nModels the number of successes in a fixed number of independent Bernoulli trials (e.g., coin flips).\nParameters: n (number of trials) and p (probability of success in each trial).\nDiscrete distribution with values from 0 to n.\nAssumes a fixed number of trials and assesses the probability of obtaining a specific number of successes.\nAppropriate when events are discrete and independent with a clear success/failure outcome.\nPoisson Distribution:\nModels the number of events occurring in a fixed interval of time or space, given a known average rate of occurrence.\nParameter: λ (average rate of occurrence).\nDiscrete distribution with values from 0 to infinity.\nAssumes an infinite number of trials or events and assesses the probability of obtaining a specific count of events.\nAppropriate for rare events with a known average rate (e.g., customer arrivals in a minute).'

# %%
# question8

# %%
mean=5
samplesize=100

sample=np.random.poisson(mean,samplesize)

meanof=np.mean(sample)
variance=np.var(sample)
print("mean",meanof)
print("var",variance)
# Out:
# mean 5.0
# var 5.0

# %%
# question9

# %%
"""Mean (μ) = n * p, where n is the number of trials and p is the probability of success.
Variance (σ^2) = n * p * (1 - p).
In the Poisson distribution:

Mean (μ) = λ, where λ is the average rate of occurrence.
Variance (σ^2) = λ.
In both distributions, the variance is directly related to the mean. Specifically:

In the Binomial distribution, the variance is a function of both the number of trials (n) and the probability of success (p). As the number of trials or the probability of success changes, it affects the spread of the distribution. When p is close to 0 or 1 (i.e., very unlikely or very likely to succeed), the variance tends to be smaller.

In the Poisson distribution, the variance is solely determined by the average rate of occurrence (λ). The variance is equal to the mean (σ^2 = λ). This means that in a Poisson distribution, the spread of the distribution is directly proportional to the average rate of occurrence.

Q10. In a norm"""
# Out:
# 'Mean (μ) = n * p, where n is the number of trials and p is the probability of success.\nVariance (σ^2) = n * p * (1 - p).\nIn the Poisson distribution:\n\nMean (μ) = λ, where λ is the average rate of occurrence.\nVariance (σ^2) = λ.\nIn both distributions, the variance is directly related to the mean. Specifically:\n\nIn the Binomial distribution, the variance is a function of both the number of trials (n) and the probability of success (p). As the number of trials or the probability of success changes, it affects the spread of the distribution. When p is close to 0 or 1 (i.e., very unlikely or very likely to succeed), the variance tends to be smaller.\n\nIn the Poisson distribution, the variance is solely determined by the average rate of occurrence (λ). The variance is equal to the mean (σ^2 = λ). This means that in a Poisson distribution, the spread of the distribution is directly proportional to the average rate of occurrence.\n\nQ10. In a norm'

# %%
# question10

# %%
"""In a normal distribution (also known as a Gaussian distribution or bell curve), the least frequent data values appear in the tails of the distribution, farthest away from the mean (average). Here's a more detailed explanation:

The normal distribution is symmetric, and its peak (highest point) is at the mean (μ).
As you move away from the mean in either direction (left or right), the data values become less frequent.
The tails of the distribution, which are the extreme values, contain the least frequent data points. These are the values that are farthest from the mean.
In a standard normal distribution (with a mean of 0 and a standard deviation of 1), the least frequent data values would be found in the tails beyond a certain number of standard deviations from the mean. For example, in a standard normal distribution, data values in the extreme tails, such as those more than 2 or 3 standard deviations away from the mean, are considered rare and infrequent.

The specific threshold for what is considered "far from the mean" and "least frequent" may vary depending on the context and the standard deviation of the distribution, but in a normal distribution, the tails always contain the least common data values.






"""
# Out:
# 'In a normal distribution (also known as a Gaussian distribution or bell curve), the least frequent data values appear in the tails of the distribution, farthest away from the mean (average). Here\'s a more detailed explanation:\n\nThe normal distribution is symmetric, and its peak (highest point) is at the mean (μ).\nAs you move away from the mean in either direction (left or right), the data values become less frequent.\nThe tails of the distribution, which are the extreme values, contain the least frequent data points. These are the values that are farthest from the mean.\nIn a standard normal distribution (with a mean of 0 and a standard deviation of 1), the least frequent data values would be found in the tails beyond a certain number of standard deviations from the mean. For example, in a standard normal distribution, data values in the extreme tails, such as those more than 2 or 3 standard deviations away from the mean, are considered rare and infrequent.\n\nThe specific thres
# ...
