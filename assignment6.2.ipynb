# %%
""" question 1 Because this method offers consistency and compatibility with the current exception handling infrastructure, it is advised to generate custom exceptions in Python by deriving from the base Exception class (or its subclasses). Your custom exception becomes a part of the standard exception hierarchy by deriving from the Exception class, which makes it simpler to understand and use in your code and enables you to take advantage of the already-existing exception handling capabilities."""
# Out:
# ' question 1 Because this method offers consistency and compatibility with the current exception handling infrastructure, it is advised to generate custom exceptions in Python by deriving from the base Exception class (or its subclasses). Your custom exception becomes a part of the standard exception hierarchy by deriving from the Exception class, which makes it simpler to understand and use in your code and enables you to take advantage of the already-existing exception handling capabilities.'

# %%
# question 2

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print("  " * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 1)

print_exception_hierarchy(BaseException)
# Out:
# BaseException
#   Exception
#     TypeError
#       FloatOperation
#       MultipartConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#       ModuleNotFoundError
#       ZipImportError
#     OSError
#       ConnectionError
#         BrokenPipeError
#         ConnectionAbortedError
#         ConnectionRefusedError
#         ConnectionResetError
#           RemoteDisconnected
#       BlockingIOError
#       ChildProcessError
#       FileExistsError
#       FileNotFoundError
#       IsADirectoryError
#       NotADirectoryError
#       InterruptedError
#         InterruptedSystemCall
#       PermissionError
#       ProcessLookupError
#       TimeoutError
#       UnsupportedOperation
#       itimer_error
#       herror
#       gaierror
#       SSLError
#         SSLCertVerificationError
#         SSLZeroReturnError
#         SSLWantWriteError
#         SSLWantReadError
#         SSLSyscallError
#         SSLEOFError
#       Error
#         SameFileError
# ...

# %%
# question 3

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero")
# Out:
# Error: Division by zero

# %%
d = {"apple": 1, "banana": 2}
try:
    value = d["orange"]
except KeyError:
    print("Error: Key not found")
# Out:
# Error: Key not found

# %%
# question 4

# %%
my_list = [1, 2, 3]
try:
    value = my_list[10]
except IndexError:
    print("Error: Index out of range")
# Out:
# Error: Index out of range

# %%
# question 5

# %%
"""ImportError: ImportError is raised when an import statement fails to find the specified module or when an import operation cannot be completed successfully for any reason.

ModuleNotFoundError: ModuleNotFoundError is a subclass of ImportError introduced in Python 3.6. It's raised when an import statement fails to locate the specified module."""
# Out:
# "ImportError: ImportError is raised when an import statement fails to find the specified module or when an import operation cannot be completed successfully for any reason.\n\nModuleNotFoundError: ModuleNotFoundError is a subclass of ImportError introduced in Python 3.6. It's raised when an import statement fails to locate the specified module."

# %%
# question 6

# %%
"""Specific Exception Handling: Catch specific exceptions rather than using a generic except clause. This allows you to handle different types of errors appropriately.

Avoid Bare Except: Avoid using bare except clauses as they catch all exceptions and make debugging difficult. Instead, specify the type of exception you expect to handle.

Use finally: Use the finally block to ensure that cleanup code (e.g., closing files, releasing resources) is executed regardless of whether an exception occurs or not.

Raising Exceptions: Raise exceptions with clear error messages to provide context about the issue. This helps in debugging and understanding the cause of the error.

Custom Exceptions: Use custom exception classes to represent specific errors in your application. This enhances code readability and maintainability.

Logging: Use the logging module to log exceptions and error messages. This aids in tracking issues and debugging."""
# Out:
# 'Specific Exception Handling: Catch specific exceptions rather than using a generic except clause. This allows you to handle different types of errors appropriately.\n\nAvoid Bare Except: Avoid using bare except clauses as they catch all exceptions and make debugging difficult. Instead, specify the type of exception you expect to handle.\n\nUse finally: Use the finally block to ensure that cleanup code (e.g., closing files, releasing resources) is executed regardless of whether an exception occurs or not.\n\nRaising Exceptions: Raise exceptions with clear error messages to provide context about the issue. This helps in debugging and understanding the cause of the error.\n\nCustom Exceptions: Use custom exception classes to represent specific errors in your application. This enhances code readability and maintainability.\n\nLogging: Use the logging module to log exceptions and error messages. This aids in tracking issues and debugging.'
