# %%
# question 1

# %%
"""Scatter Plot: Scatter plots are used to visualize the relationship between two continuous variables. They help identify patterns, correlations, and outliers in data.

Bar Plot: Bar plots are used to display and compare categorical data. They are suitable for showing the distribution of a single categorical variable or comparing multiple categories.

Box Plot: Box plots are useful for visualizing the distribution and spread of numerical data. They show the median, quartiles, and potential outliers in the data.

Heatmap: Heatmaps are used to visualize the relationships between two categorical variables. They are particularly helpful for displaying correlation matrices and complex datasets.

Line Plot: Line plots are used to represent data points connected by lines. They are suitable for visualizing trends and changes in data over a continuous variable, often used for time series data."""
# Out:
# 'Scatter Plot: Scatter plots are used to visualize the relationship between two continuous variables. They help identify patterns, correlations, and outliers in data.\n\nBar Plot: Bar plots are used to display and compare categorical data. They are suitable for showing the distribution of a single categorical variable or comparing multiple categories.\n\nBox Plot: Box plots are useful for visualizing the distribution and spread of numerical data. They show the median, quartiles, and potential outliers in the data.\n\nHeatmap: Heatmaps are used to visualize the relationships between two categorical variables. They are particularly helpful for displaying correlation matrices and complex datasets.\n\nLine Plot: Line plots are used to represent data points connected by lines. They are suitable for visualizing trends and changes in data over a continuous variable, often used for time series data.'

# %%
# question2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fmri=sns.load_dataset("fmri")

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x="timepoint",y="signal",data=fmri,style="region")
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
# question 3

# %%
titanic=sns.load_dataset("titanic")

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
sns.boxplot(x="pclass", y="age", data=titanic)
plt.subplot(1, 2, 2)
sns.boxplot(x="pclass", y="fare", data=titanic)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
# question4

# %%
daimond=sns.load_dataset("diamonds")

# %%
daimond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.histplot(data=daimond,x="price",hue="cut")
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %%
# question 5

# %%
iris_data = sns.load_dataset("iris")

# %%
sns.pairplot(data=iris_data, hue="species")

# %%
# question6

# %%
flights_data = sns.load_dataset("flights")

# %%
flights_pivot = flights_data.pivot_table(index="month", columns="year", values="passengers")


plt.figure(figsize=(10, 6))
sns.heatmap(data=flights_pivot, cmap="YlGnBu", annot=True, fmt="d", linewidths=0.5)
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>
